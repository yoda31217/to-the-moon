# %% [markdown]
# Markdown test:
#
# # Hello world
#
# - 123
# - 456
#
# Just text.

# %%
# Random code + local imoport test

from simulator.utils.gits import get_version


qwe = 123

print(get_version())
# Out:
# hash: 0xc7bbe2c3... from 2023-06-17 17:32:13+03:00

# %%
# random code + local import + library import + data frame output test

from datetime import date, timedelta
from simulator.binance.binance_k_line_repository import load_k_lines

date_from: date = date.today() - timedelta(days=3 + 6)
date_to: date = date.today() - timedelta(days=3)
symbol: str = "ETHUSDT"
k_lines = load_k_lines(symbol, date_from, date_to)

k_lines
# Out:
#       open_timestamp_millis  open_price  high_price  low_price  close_price  \
# 0             1686182400000     1831.32     1831.94    1830.58      1831.94
# 1             1686182460000     1831.94     1831.94    1831.14      1831.14
# 2             1686182520000     1831.15     1831.70    1831.14      1831.68
# 3             1686182580000     1831.68     1831.85    1831.40      1831.40
# 4             1686182640000     1831.41     1831.98    1831.40      1831.96
# ...                     ...         ...         ...        ...          ...
# 1435          1686786900000     1649.59     1649.60    1649.08      1649.46
# 1436          1686786960000     1649.46     1650.13    1648.81      1649.65
# 1437          1686787020000     1649.64     1650.28    1649.64      1649.92
# 1438          1686787080000     1649.93     1650.20    1649.69      1650.19
# 1439          1686787140000     1650.19     1650.30    1650.03      1650.18
#
# ...
