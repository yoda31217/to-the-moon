# %%
# Skip these 2 sections. Technical things
# @formatter:off

# %%
# %reload_ext autoreload
# %autoreload 2
# @formatter:on

# %% [markdown]
# # Ticks

# %%
from report.report import load_and_report_ticks

ticks = load_and_report_ticks(f"../../../ttm-data/ETHUSDT-1s-*.csv", 0.01)
# Out:
#            timestamp  bid_price  ask_price
# 0      1677628800000    1605.24    1605.25
# 1      1677628801000    1605.46    1605.47
# 2      1677628802000    1605.46    1605.47
# 3      1677628803000    1605.46    1605.47
# 4      1677628804000    1605.47    1605.48
# ...              ...        ...        ...
# 86395  1681775995000    2074.00    2074.01
# 86396  1681775996000    2074.00    2074.01
# 86397  1681775997000    2074.00    2074.01
# 86398  1681775998000    2074.00    2074.01
# 86399  1681775999000    2074.00    2074.01
#
# [4142381 rows x 3 columns]

# %% [markdown]
# # Simulator Setup

# %%
# @formatter:off

# %%
# %%time
# @formatter:on

from trade.trade_simulator import TradeSimulator

trade_simulator: TradeSimulator = TradeSimulator(ticks)
# Out:
# CPU times: user 51.6 s, sys: 784 ms, total: 52.4 s
# Wall time: 52.5 s

# %% [markdown]
# # Simulation

# %%
from report.report import simulate_and_report
from bot.bot_0_strategy import Bot0Strategy

# 'orders: 30,049, avg. price margin: 1.99, avg. profit: -0.04, cum. profit: -1199.56'
simulate_and_report([
    Bot0Strategy(0.001),
    Bot0Strategy(0.0025),
    Bot0Strategy(0.005),
    Bot0Strategy(0.0075),
    Bot0Strategy(0.01),
    Bot0Strategy(0.025),
    Bot0Strategy(0.05),
    Bot0Strategy(0.1),
], trade_simulator)
# Out:
# 'orders=30,049 avg_tick_price_change=0.06 tx_avg_price_margin=1.99 tx_avg_prof=-0.04 tx_cum_prof=-1199.56'
# 'orders=5,753 avg_tick_price_change=0.06 tx_avg_price_margin=4.63 tx_avg_prof=-0.01 tx_cum_prof=-36.66'
# 'orders=1,543 avg_tick_price_change=0.06 tx_avg_price_margin=9.01 tx_avg_prof=0.01 tx_cum_prof=14.95'
# 'orders=683 avg_tick_price_change=0.06 tx_avg_price_margin=13.33 tx_avg_prof=0.03 tx_cum_prof=19.44'
# 'orders=380 avg_tick_price_change=0.06 tx_avg_price_margin=17.68 tx_avg_prof=-0.68 tx_cum_prof=-258.47'
# 'orders=55 avg_tick_price_change=0.06 tx_avg_price_margin=42.98 tx_avg_prof=-10.23 tx_cum_prof=-562.42'
# 'orders=18 avg_tick_price_change=0.06 tx_avg_price_margin=83.84 tx_avg_prof=-10.16 tx_cum_prof=-182.88'
# 'orders=5 avg_tick_price_change=0.06 tx_avg_price_margin=142.69 tx_avg_prof=-68.05 tx_cum_prof=-340.23'
