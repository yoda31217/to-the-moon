# %%
# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# # Ticks

# %%
from report.report import load_and_report_ticks

ticks = load_and_report_ticks(
    csv_files_pattern=f"./ttm-data/ETHUSDT-1s-*.csv",
    symbol_ask_bid_price_difference=0.01)
# Out:
#            timestamp  bid_price  ask_price
# 0      1677628800000    1605.24    1605.25
# 1      1677628801000    1605.46    1605.47
# 2      1677628802000    1605.46    1605.47
# 3      1677628803000    1605.46    1605.47
# 4      1677628804000    1605.47    1605.48
# ...              ...        ...        ...
# 86395  1681775995000    2074.00    2074.01
# 86396  1681775996000    2074.00    2074.01
# 86397  1681775997000    2074.00    2074.01
# 86398  1681775998000    2074.00    2074.01
# 86399  1681775999000    2074.00    2074.01
#
# [4142381 rows x 3 columns]

# %% [markdown]
# # Simulator Setup

# %%
from trade.trade_simulator import TradeSimulator

trade_simulator: TradeSimulator = TradeSimulator(ticks)

# %% [markdown]
# # Simulation

# %%
from report.report import simulate_and_report
from bot.bot_0_strategy import Bot0Strategy

simulate_and_report([
    # 'orders=30,049 interval_days=48.0 avg_tick_price_change=0.06 str=Bot0[0.10%, not_inverted]
    # tx_avg_price_margin=1.99 tx_avg_prof=-0.04 tx_cum_prof=-1199.56'
    Bot0Strategy(price_step_ratio=0.001, inverted=False),
    Bot0Strategy(price_step_ratio=0.0025, inverted=False),
    Bot0Strategy(price_step_ratio=0.005, inverted=False),
    Bot0Strategy(price_step_ratio=0.0075, inverted=False),
    Bot0Strategy(price_step_ratio=0.01, inverted=False),
    Bot0Strategy(price_step_ratio=0.025, inverted=False),
    Bot0Strategy(price_step_ratio=0.05, inverted=False),
    Bot0Strategy(price_step_ratio=0.1, inverted=False),

    Bot0Strategy(price_step_ratio=0.001, inverted=True),
    Bot0Strategy(price_step_ratio=0.0025, inverted=True),
    Bot0Strategy(price_step_ratio=0.005, inverted=True),
    Bot0Strategy(price_step_ratio=0.0075, inverted=True),
    Bot0Strategy(price_step_ratio=0.01, inverted=True),
    Bot0Strategy(price_step_ratio=0.025, inverted=True),
    Bot0Strategy(price_step_ratio=0.05, inverted=True),
    Bot0Strategy(price_step_ratio=0.1, inverted=True),
], trade_simulator)
# Out:
# 'orders=30,049 interval_days=48.0 avg_tick_price_change=0.06 str=Bot0[0.10%, not_inverted] tx_avg_price_margin=1.99 tx_avg_prof=-0.04 tx_cum_prof=-1199.56'
# 'orders=5,753 interval_days=48.0 avg_tick_price_change=0.06 str=Bot0[0.25%, not_inverted] tx_avg_price_margin=4.63 tx_avg_prof=-0.01 tx_cum_prof=-36.66'
# 'orders=1,543 interval_days=48.0 avg_tick_price_change=0.06 str=Bot0[0.50%, not_inverted] tx_avg_price_margin=9.01 tx_avg_prof=0.01 tx_cum_prof=14.95'
# 'orders=683 interval_days=48.0 avg_tick_price_change=0.06 str=Bot0[0.75%, not_inverted] tx_avg_price_margin=13.33 tx_avg_prof=0.03 tx_cum_prof=19.44'
# 'orders=380 interval_days=48.0 avg_tick_price_change=0.06 str=Bot0[1.00%, not_inverted] tx_avg_price_margin=17.68 tx_avg_prof=-0.68 tx_cum_prof=-258.47'
# 'orders=55 interval_days=48.0 avg_tick_price_change=0.06 str=Bot0[2.50%, not_inverted] tx_avg_price_margin=42.98 tx_avg_prof=-10.23 tx_cum_prof=-562.42'
# 'orders=18 interval_days=48.0 avg_tick_price_change=0.06 str=Bot0[5.00%, not_inverted] tx_avg_price_margin=83.84 tx_avg_prof=-10.16 tx_cum_prof=-182.88'
# 'orders=5 interval_days=48.0 avg_tick_price_change=0.06 str=Bot0[10.00%, not_inverted] tx_avg_price_margin=142.69 tx_avg_prof=-68.05 tx_cum_prof=-340.23'
# 'orders=30,049 interval_days=48.0 avg_tick_price_change=0.06 str=Bot0[0.10%, inverted] tx_avg_price_margin=1.99 tx_avg_prof=0.02 tx_cum_prof=552.07'
# 'orders=5,753 interval_days=48.0 avg_tick_price_change=0.06 str=Bot0[0.25%, inverted] tx_avg_price_margin=4.63 tx_avg_prof=-0.01 tx_cum_prof=-69.92'
# 'orders=1,543 interval_days=48.0 avg_tick_price_change=0.06 str=Bot0[0.50%, inverted] tx_avg_price_margin=9.01 tx_avg_prof=-0.03 tx_cum_prof=-47.41'
# 'orders=683 interval_days=48.0 avg_tick_price_change=0.06 str=Bot0[0.75%, inverted] tx_avg_price_margin=13.33 tx_avg_prof=-0.11 tx_cum_prof=-77.87'
# 'orders=380 interval_days=48.0 avg_tick_price_change=0.06 str=Bot0[1.00%, inverted] tx_avg_price_margin=17.67 tx_avg_prof=0.67 tx_cum_prof=256.29'
# 'orders=55 interval_days=48.0 avg_tick_price_change=0.06 str=Bot0[2.50%, inverted] tx_avg_price_margin=42.97 tx_avg_prof=10.21 tx_cum_prof=561.36'
# 'orders=18 interval_days=48.0 avg_tick_price_change=0.06 str=Bot0[5.00%, inverted] tx_avg_price_margin=83.84 tx_avg_prof=10.14 tx_cum_prof=182.52'
# 'orders=5 interval_days=48.0 avg_tick_price_change=0.06 str=Bot0[10.00%, inverted] tx_avg_price_margin=142.69 tx_avg_prof=68.03 tx_cum_prof=340.13'
