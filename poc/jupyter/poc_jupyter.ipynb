# %% [markdown]
# # Hello world
#
# - 123
# - 456
#
# Just text.

# %%
from utils.gits import get_version


qwe = 123

print(get_version())
# Out:
# hash: 0x602883da... from 2023-06-01 12:30:47+03:00
